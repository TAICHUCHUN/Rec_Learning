# %%
import numpy as np
from sklearn.feature_extraction import DictVectorizer
from pyfm import pylibfm

# Read in data
def loadData(filename,path="ml-100k/"):
    data = []
    y = []
    users=set()
    items=set()
    with open(path+filename) as f:
        for line in f:
            (user,movieid,rating,ts)=line.split('\t')
            data.append({ "user_id": str(user), "movie_id": str(movieid)})
            y.append(float(rating))
            users.add(user)
            items.add(movieid)

    return (data, np.array(y), users, items)

(train_data, y_train, train_users, train_items) = loadData("ua.base")
(test_data, y_test, test_users, test_items) = loadData("ua.test")
v = DictVectorizer()
X_train = v.fit_transform(train_data)
X_test = v.transform(test_data)

# Build and train a Factorization Machine
fm = pylibfm.FM(num_factors=10, num_iter=100, verbose=True, task="regression", initial_learning_rate=0.001, learning_rate_schedule="optimal")

fm.fit(X_train,y_train)
# Out:
# Creating validation dataset of 0.01 of training for adaptive regularization
# -- Epoch 1
# Training MSE: 0.59485
# -- Epoch 2
# Training MSE: 0.51807
# -- Epoch 3
# Training MSE: 0.49040
# -- Epoch 4
# Training MSE: 0.47463
# -- Epoch 5
# Training MSE: 0.46410
# -- Epoch 6
# Training MSE: 0.45659
# -- Epoch 7
# Training MSE: 0.45094
# -- Epoch 8
# Training MSE: 0.44654
# -- Epoch 9
# Training MSE: 0.44269
# -- Epoch 10
# Training MSE: 0.43948
# -- Epoch 11
# Training MSE: 0.43671
# -- Epoch 12
# Training MSE: 0.43437
# -- Epoch 13
# Training MSE: 0.43230
# -- Epoch 14
# Training MSE: 0.43030
# -- Epoch 15
# Training MSE: 0.42842
# -- Epoch 16
# Training MSE: 0.42684
# -- Epoch 17
# Training MSE: 0.42543
# -- Epoch 18
# Training MSE: 0.42397
# -- Epoch 19
# Training MSE: 0.42254
# -- Epoch 20
# Training MSE: 0.42136
# -- Epoch 21
# Training MSE: 0.41997
# -- Epoch 22
# Training MSE: 0.41879
# -- Epoch 23
# Training MSE: 0.41757
# -- Epoch 24
# Training MSE: 0.41633
# -- Epoch 25
# Training MSE: 0.41529
# -- Epoch 26
# Training MSE: 0.41408
# -- Epoch 27
# Training MSE: 0.41283
# -- Epoch 28
# Training MSE: 0.41158
# -- Epoch 29
# Training MSE: 0.41045
# -- Epoch 30
# Training MSE: 0.40918
# -- Epoch 31
# Training MSE: 0.40797
# -- Epoch 32
# Training MSE: 0.40658
# -- Epoch 33
# Training MSE: 0.40535
# -- Epoch 34
# Training MSE: 0.40391
# -- Epoch 35
# Training MSE: 0.40255
# -- Epoch 36
# Training MSE: 0.40111
# -- Epoch 37
# Training MSE: 0.39963
# -- Epoch 38
# Training MSE: 0.39816
# -- Epoch 39
# Training MSE: 0.39644
# -- Epoch 40
# Training MSE: 0.39486
# -- Epoch 41
# Training MSE: 0.39324
# -- Epoch 42
# Training MSE: 0.39150
# -- Epoch 43
# Training MSE: 0.38970
# -- Epoch 44
# Training MSE: 0.38791
# -- Epoch 45
# Training MSE: 0.38617
# -- Epoch 46
# Training MSE: 0.38436
# -- Epoch 47
# Training MSE: 0.38236
# -- Epoch 48
# Training MSE: 0.38045
# -- Epoch 49
# Training MSE: 0.37856
# -- Epoch 50
# Training MSE: 0.37664
# -- Epoch 51
# Training MSE: 0.37470
# -- Epoch 52
# Training MSE: 0.37271
# -- Epoch 53
# Training MSE: 0.37069
# -- Epoch 54
# Training MSE: 0.36884
# -- Epoch 55
# Training MSE: 0.36682
# -- Epoch 56
# Training MSE: 0.36491
# -- Epoch 57
# Training MSE: 0.36298
# -- Epoch 58
# Training MSE: 0.36108
# -- Epoch 59
# Training MSE: 0.35921
# -- Epoch 60
# Training MSE: 0.35735
# -- Epoch 61
# Training MSE: 0.35563
# -- Epoch 62
# Training MSE: 0.35386
# -- Epoch 63
# Training MSE: 0.35216
# -- Epoch 64
# Training MSE: 0.35036
# -- Epoch 65
# Training MSE: 0.34887
# -- Epoch 66
# Training MSE: 0.34721
# -- Epoch 67
# Training MSE: 0.34573
# -- Epoch 68
# Training MSE: 0.34421
# -- Epoch 69
# Training MSE: 0.34278
# -- Epoch 70
# Training MSE: 0.34142
# -- Epoch 71
# Training MSE: 0.34009
# -- Epoch 72
# Training MSE: 0.33882
# -- Epoch 73
# Training MSE: 0.33763
# -- Epoch 74
# Training MSE: 0.33642
# -- Epoch 75
# Training MSE: 0.33532
# -- Epoch 76
# Training MSE: 0.33428
# -- Epoch 77
# Training MSE: 0.33324
# -- Epoch 78
# Training MSE: 0.33229
# -- Epoch 79
# Training MSE: 0.33142
# -- Epoch 80
# Training MSE: 0.33059
# -- Epoch 81
# Training MSE: 0.32971
# -- Epoch 82
# Training MSE: 0.32894
# -- Epoch 83
# Training MSE: 0.32817
# -- Epoch 84
# Training MSE: 0.32757
# -- Epoch 85
# Training MSE: 0.32694
# -- Epoch 86
# Training MSE: 0.32630
# -- Epoch 87
# Training MSE: 0.32577
# -- Epoch 88
# Training MSE: 0.32530
# -- Epoch 89
# Training MSE: 0.32472
# -- Epoch 90
# Training MSE: 0.32433
# -- Epoch 91
# Training MSE: 0.32391
# -- Epoch 92
# Training MSE: 0.32359
# -- Epoch 93
# Training MSE: 0.32316
# -- Epoch 94
# Training MSE: 0.32286
# -- Epoch 95
# Training MSE: 0.32252
# -- Epoch 96
# Training MSE: 0.32217
# -- Epoch 97
# Training MSE: 0.32203
# -- Epoch 98
# Training MSE: 0.32176
# -- Epoch 99
# Training MSE: 0.32152
# -- Epoch 100
# Training MSE: 0.32131
